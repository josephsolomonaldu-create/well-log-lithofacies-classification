# %% [markdown]
# # Step 02. Data Understanding

# %% [markdown]
# ## Objective
#
# The objective of this notebook is to explore and understand the structure, quality, and characteristics of the well log dataset before modeling.
#
# Specifically, this stage aims to:
#
# - Examine dataset dimensions and feature types
#
# - Identify numerical and categorical variables
#
# - Assess data quality (missing values, duplicates, inconsistencies)
#
# - Understand the distribution of lithofacies classes
#
# - Analyze statistical properties of petrophysical logs
#
# - Detect potential class imbalance issues
#
# This step ensures that subsequent preprocessing and modeling decisions are informed by a solid understanding of the data.

# %% [markdown]
# ## 📊 1. Load and Inspect the Dataset

# %%
import pandas as pd

df = pd.read_csv('facies_data.csv')

df.head()
# Out:
#    Facies Formation  Well Name   Depth     GR  ILD_log10  DeltaPHI   PHIND  \
# 0       3     A1 SH  SHRIMPLIN  2793.0  77.45      0.664       9.9  11.915
# 1       3     A1 SH  SHRIMPLIN  2793.5  78.26      0.661      14.2  12.565
# 2       3     A1 SH  SHRIMPLIN  2794.0  79.05      0.658      14.8  13.050
# 3       3     A1 SH  SHRIMPLIN  2794.5  86.10      0.655      13.9  13.115
# 4       3     A1 SH  SHRIMPLIN  2795.0  74.58      0.647      13.5  13.300
#
#     PE  NM_M  RELPOS
# 0  4.6     1   1.000
# 1  4.1     1   0.979
# 2  3.6     1   0.957
# 3  3.5     1   0.936
# 4  3.4     1   0.915

# %% [markdown]
# ## 2. Basic Information

# %%
# shows the number of rows and columns
df.shape
# Out:
# (3232, 11)

# %%
# shows the names of columns
df.columns
# Out:
# Index(['Facies', 'Formation', 'Well Name', 'Depth', 'GR', 'ILD_log10',
#        'DeltaPHI', 'PHIND', 'PE', 'NM_M', 'RELPOS'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3232 entries, 0 to 3231
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Facies     3232 non-null   int64
#  1   Formation  3232 non-null   object
#  2   Well Name  3232 non-null   object
#  3   Depth      3232 non-null   float64
#  4   GR         3232 non-null   float64
#  5   ILD_log10  3232 non-null   float64
#  6   DeltaPHI   3232 non-null   float64
#  7   PHIND      3232 non-null   float64
#  8   PE         3232 non-null   float64
#  9   NM_M       3232 non-null   int64
#  10  RELPOS     3232 non-null   float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 277.9+ KB

# %% [markdown]
# # 3. Check Missing Values

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Facies       0
# Formation    0
# Well Name    0
# Depth        0
# GR           0
# ILD_log10    0
# DeltaPHI     0
# PHIND        0
# PE           0
# NM_M         0
# RELPOS       0
# dtype: int64

# %% [markdown]
# # 4. Identify Target Column

# %%
df['Facies'].value_counts()
# Out:
# Facies
# 2    738
# 3    615
# 8    498
# 6    462
# 1    259
# 5    217
# 4    184
# 9    161
# 7     98
# Name: count, dtype: int64

# %% [markdown]
# # 5. Check Class Balance

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.countplot(x='Facies', data=df)
plt.title("Facies Distribution")
plt.show()

# %% [markdown]
# ## Countplot insight:
#
# - It shows the distribution of the target variable across classes and helps identify class imbalance in the dataset

# %% [markdown]
# ## 6. Statistical Summary

# %%
df.describe()
# Out:
#             Facies        Depth           GR    ILD_log10     DeltaPHI  \
# count  3232.000000  3232.000000  3232.000000  3232.000000  3232.000000
# mean      4.422030  2875.824567    66.135769     0.642719     3.559642
# std       2.504243   131.006274    30.854826     0.241845     5.228948
# min       1.000000  2573.500000    13.250000    -0.025949   -21.832000
# 25%       2.000000  2791.000000    46.918750     0.492750     1.163750
# 50%       4.000000  2893.500000    65.721500     0.624437     3.500000
# 75%       6.000000  2980.000000    79.626250     0.812735     6.432500
# max       9.000000  3122.500000   361.150000     1.480000    18.600000
#
#              PHIND           PE         NM_M       RELPOS
# count  3232.000000  3232.000000  3232.000000  3232.000000
# mean     13.483213     3.725014     1.498453     0.520287
# std       7.698980     0.896152     0.500075     0.286792
# min       0.550000     0.200000     1.000000     0.010000
# ...

# %% [markdown]
# # Conclusion
#
# This notebook focused on understanding and exploring the well log dataset used for lithofacies classification and reservoir characterization. The analysis provided insights into the structure, distribution, and characteristics of the petrophysical data prior to machine learning model development.
#
# Data exploration and visualization helped identify important features, class distributions, potential data imbalances, and relationships between well log measurements and lithofacies classes. Preliminary statistical analysis also improved understanding of feature variability and subsurface geological patterns represented within the dataset.
#
# Furthermore, the notebook established the importance of proper data understanding as a critical step in building reliable and interpretable machine learning models. The insights obtained from this stage provide a strong foundation for subsequent preprocessing, feature engineering, model training, and evaluation workflows.
#
# Overall, the notebook enhanced understanding of the dataset and prepared the data for effective application of machine learning techniques in intelligent lithofacies prediction and reservoir characterization.
